# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_regression

# %%
X ,y =make_regression(n_samples=1000 , n_features =2 , n_targets=1, noise =3.0)

# %%
X
# Out:
# array([[ 0.4224162 , -0.75493202],
#        [ 0.87865484, -1.61258067],
#        [-0.65546689,  0.2692027 ],
#        ...,
#        [ 0.87179472, -0.06561069],
#        [-1.13634103, -0.39717412],
#        [ 1.65121395, -0.57034589]], shape=(1000, 2))

# %%
pd.DataFrame(X)
# Out:
#             0         1
# 0    0.422416 -0.754932
# 1    0.878655 -1.612581
# 2   -0.655467  0.269203
# 3    0.330440 -1.790673
# 4    0.486589  1.535027
# ..        ...       ...
# 995  1.370454  0.123788
# 996  0.102128 -0.741953
# 997  0.871795 -0.065611
# 998 -1.136341 -0.397174
# 999  1.651214 -0.570346
#
# [1000 rows x 2 columns]

# %%
sns.scatterplot(x=pd.DataFrame(X)[0], y=pd.DataFrame(X)[1] , hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y , test_size=0.25 , random_state=42)

# %%
X_train.shape
# Out:
# (750, 2)

# %%
X_test.shape
# Out:
# (250, 2)

# %%
y_test.shape
# Out:
# (250,)

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel ='linear')

# %%
svr.fit(X_train , y_train)
# Out:
# SVR(kernel='linear')

# %%
svr.coef_
# Out:
# array([[95.93523283, 14.66381982]])

# %% [markdown]
# ## Prediction

# %%
y_pred = svr.predict(X_test)

# %%
y_pred
# Out:
# array([ -81.85815419,  -18.54518936,    5.85013   , -189.96946027,
#          73.43437399,   16.40062811,  -26.79862699,  124.66849729,
#          45.52944735,  -52.95495889,  -96.38895619, -174.68421638,
#        -227.92404297, -100.69098795,   90.10127226,  -70.50766102,
#         -17.46237468, -125.77028561,   -7.19986601,   12.43832678,
#         143.86455889,   30.87940385, -214.25491315,    8.72113618,
#           4.65047928,   78.24272697,   80.8813803 , -224.77714624,
#         102.76138275, -138.02974882,  -39.71332107, -166.48613569,
#          41.14216291,  -15.36518993,  -15.83733558, -138.33127028,
#         -50.80498648,  -55.2291984 ,  185.85852954,   19.23861453,
#         132.26943205,  -27.09258973,  -58.55574619, -173.43800055,
#         -38.60771201,  102.36371388,   46.36516819,  174.13630094,
#         -60.23706738,   -8.46999321,  -85.44471822,   73.49762106,
#          21.71219335,   14.83019997,  -68.27323277,   93.34303093,
#         -33.20946   ,   -8.52546958,   34.31086394,   68.90509519,
#         -93.28446277,   -1.04694674,  -94.98569379,  -47.07582703,
#         -18.53163211,   60.32570581,   -9.47143336,  159.1548776 ,
#         -27.04032418,  -71.41620032,   26.1376449 ,   76.52948599,
#          60.73763882,  -57.95037522,   65.82992764,   68.40683087,
#         -25.04104994,  -68.18335836,   70.3269587 ,   69.46463323,
#         -14.93498105,  -50.31117326,  -86.91823178,  151.11014444,
#         -99.83628399,  -27.97268175, -114.86097052, -163.25371614,
#           9.56855337, -124.82278002,   59.51646158,  240.39859673,
#        -287.12908919,  166.79245783, -153.16229631,  111.06314502,
#        -102.11314736, -146.0595418 ,  103.08413775,   64.11303278,
#         -39.51374184,    9.78777363,  -28.59369294,  -39.53946146,
#         303.88618441,   -3.50806196, -163.81472165,  -84.42473157,
#        -2.06620734e+01, -1.32909593e+02, -1.48643527e+02,  4.36739792e+01,
#        -4.45692943e+01, -2.75140679e+01,  1.44669965e+01,  1.09376640e+02,
#         8.09924039e+00, -3.26084442e+01, -4.36494257e+01, -8.31215091e+01,
#        -1.59109387e+01, -1.11352514e+02, -1.22995247e+02,  5.35461711e+01,
#        -1.71514180e+02, -4.61875120e+01, -2.34008725e+01, -2.80759142e+01,
#         7.56402742e+01, -2.01099231e+01, -1.89453609e+02,  8.21678894e+01,
#         6.98232756e+01,  4.51758842e+00,  4.21861094e+01, -6.37565569e+01,
#         3.40275302e+01, -4.28830873e+01,  4.35911871e+01,  1.50403209e+01,
#         3.65735815e+01, -1.58707329e+02,  8.96802553e+01,  6.84768112e+01,
#        -9.33050134e+00, -7.11804244e+01, -2.93018810e+00,  1.39071915e+02,
#         1.47982402e+00,  5.13380931e+01, -8.18586998e+01,  8.08084601e+01,
#        -5.32807590e+01, -4.26751943e+01, -7.37394719e+01,  6.19385722e+01,
#         2.73759319e+00,  4.76760351e+01, -2.42693324e+02, -1.20194849e+02,
#        -7.87513585e+01, -5.94678817e+01, -8.99619069e+01, -2.93205404e+01,
#         1.24975312e+02,  1.76190067e+02, -1.81804830e+02,  8.03334060e+01,
#         1.28731078e+02, -3.71068458e+00,  1.00703207e+01,  1.48441213e+02,
#        -6.72742574e-01, -4.57116879e+01,  1.68924781e+01, -2.84645713e+01,
#         4.70661663e+00,  3.64274598e+01,  8.32249378e+01,  7.12059542e+01,
#        -1.23939970e+02,  9.11797832e+01,  4.38786442e+01, -1.40732876e+02,
#         9.81428395e+01,  6.89364138e+01])

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_pred ,y_test)*100)
# Out:
# 99.90374284057341

# %% [markdown]
# ## hyperparameter tuining

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'C':[0.1,1,10,100,100],
    'gamma':[1,0.1,0.001,0.0001],
    'kernel':['linear','rbf'],
    'epsilion':[0.01,0.1,0.1]
}

# %%
grid = GridSearchCV(estimator=model,param_grid = param_grid,refit=True ,cv =5 , verbose=2, scoring='r2',)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 grid = GridSearchCV(estimator=model,param_grid = param_grid,refit=True ,cv =5 , verbose=2, scoring='r2',)
#
# NameError: name 'model' is not defined

# %%
grid.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 grid.fit(X_train , y_train)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1131, in BaseSearchCV.fit(self, X, y, **params)
#    1128     return results
#    1130 if "callback_ctx" in signature(self._run_search).parameters:
# -> 1131     self._run_search(evaluate_candidates, callback_ctx=root_callback_ctx)
#    1132 else:
#    1133     # custom search classes
#    1134     self._run_search(evaluate_candidates)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1718, in GridSearchCV._run_search(self, evaluate_candidates, callback_ctx)
#    1710 candidate_params = ParameterGrid(self.param_grid)
#    1712 search_ctx = callback_ctx.subcontext(
#    1713     task_name="search",
#    1714     max_subtasks=len(candidate_params) * self.n_splits_,
#    1715     sequential_subtasks=False,
#    1716 ).call_on_fit_task_begin(estimator=self)
# -> 1718 evaluate_candidates(ParameterGrid(self.param_grid), callback_ctx=search_ctx)
#    1720 search_ctx.call_on_fit_task_end(estimator=self)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1080, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results, callback_ctx)
#    1077 else:
#    1078     evaluation_contexts = [None] * len(candidate_split_pairs)
# -> 1080 out = parallel(
#    1081     delayed(_fit_and_score)(
#    1082         clone(base_estimator),
#    1083         X,
#    1084         y,
#    1085         train=train,
#    1086         test=test,
#    1087         parameters=parameters,
#    1088         split_progress=(split_idx, n_splits),
#    1089         candidate_progress=(cand_idx, n_candidates),
#    1090         **fit_and_score_kwargs,
#    1091         caller=self,
#    1092         callback_ctx=evaluation_ctx,
#    1093     )
#    1094     for (
#    1095         ((cand_idx, parameters), (split_idx, (train, test))),
#    1096         evaluation_ctx,
#    1097     ) in zip(candidate_split_pairs, evaluation_contexts)
#    1098 )
#    1100 if len(out) < 1:
#    1101     raise ValueError(
#    1102         "No fits were performed. "
#    1103         "Was the CV iterator empty? "
#    1104         "Were there no candidates?"
#    1105     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:828, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score, caller, callback_ctx)
#     821 score_params_test = _check_method_params(X, params=score_params, indices=test)
#     823 if parameters is not None:
#     824     # here we clone the parameters, since sometimes the parameters
#     825     # themselves might be estimators, e.g. when we search over different
#     826     # estimators in a pipeline.
#     827     # ref: https://github.com/scikit-learn/scikit-learn/pull/26786
# --> 828     estimator = estimator.set_params(**clone(parameters, safe=False))
#     830 start_time = time.time()
#     832 X_train, y_train = _safe_split(estimator, X, y, train)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:428, in BaseEstimator.set_params(self, **params)
#     426 if key not in valid_params:
#     427     local_valid_params = self._get_param_names()
# --> 428     raise ValueError(
#     429         f"Invalid parameter {key!r} for estimator {self}. "
#     430         f"Valid parameters are: {local_valid_params!r}."
#     431     )
#     433 if delim:
#     434     nested_params[key][sub_key] = value
#
# ValueError: Invalid parameter 'epsilion' for estimator SVR(C=0.1). Valid parameters are: ['C', 'cache_size', 'coef0', 'degree', 'epsilon', 'gamma', 'kernel', 'max_iter', 'shrinking', 'tol', 'verbose'].
