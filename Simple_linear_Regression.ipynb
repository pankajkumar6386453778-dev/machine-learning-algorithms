# %% [markdown]
# ## Simple Linear Regression

# %%
#1 - Read the dataset
#2 - EDA , FE
#3 - Divide the dataset into independent and dependent feature
#4 - Further decide the dataset into the train and test
#5 - Standard scaling on the train and test Data
#5 - Training the model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1 - Load the Dataset

# %%
df = pd.read_csv('heights.csv')

# %%
df.head()
# Out:
#    height  weight
# 0   65.78  112.99
# 1   71.52  136.49
# 2   69.40  153.03
# 3   68.22  142.34
# 4   67.79  144.30

# %%
plt.scatter(df['weight'],df['height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  200 non-null    float64
#  1   weight  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#            height      weight
# count  200.000000  200.000000
# mean    67.949800  127.221950
# std      1.940363   11.960959
# min     63.430000   97.900000
# 25%     66.522500  119.895000
# 50%     67.935000  127.875000
# 75%     69.202500  136.097500
# max     73.900000  158.960000

# %%
df.isnull().sum()
# Out:
# height    0
# weight    0
# dtype: int64

# %%
df.head()
# Out:
#    height  weight
# 0   65.78  112.99
# 1   71.52  136.49
# 2   69.40  153.03
# 3   68.22  142.34
# 4   67.79  144.30

# %% [markdown]
# ## Divide the dataset independent and dependent  dataset

# %%
X= df[['weight']]
y = df[['height']]

# %%
X
# Out:
#      weight
# 0    112.99
# 1    136.49
# 2    153.03
# 3    142.34
# 4    144.30
# ..      ...
# 195  120.84
# 196  115.78
# 197  128.30
# 198  127.47
# 199  127.88
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      height
# 0     65.78
# 1     71.52
# 2     69.40
# 3     68.22
# 4     67.79
# ..      ...
# 195   65.80
# 196   66.11
# 197   68.24
# 198   68.02
# 199   71.39
#
# [200 rows x 1 columns]

# %%
X.shape , y.shape
# Out:
# ((200, 1), (200, 1))

# %% [markdown]
# ## Further divide the dataset into train and test dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train ,X_test , y_train,y_test = train_test_split(X,y , test_size=20 , random_state=42)

# %%
X_train.shape
# Out:
# (180, 1)

# %%
X_test.shape
# Out:
# (20, 1)

# %%
y_train.shape , y_test.shape
# Out:
# ((180, 1), (20, 1))

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
## X_train me fit ka use krte 
## X_test me transform

# %%
X_train= scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.40905393],
#        [ 1.1155655 ],
#        [-2.04650459],
#        [ 1.01045036],
#        [ 1.13624389],
#        [ 0.1290341 ],
#        [-0.20009691],
#        [-0.382756  ],
#        [ 1.05525354],
#        [ 0.14712768],
#        [ 1.32838057],
#        [-1.5407457 ],
#        [ 0.01616456],
#        [-0.98501403],
#        [ 0.07044533],
#        [-0.703271  ],
#        [ 2.48550867],
#        [-0.5369823 ],
#        [ 2.4407055 ],
#        [-2.0266878 ]])

# %%
plt.scatter(X_train , y_train)

# %% [markdown]
# ## 6 - Training Model

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor
# Out:
# LinearRegression()

# %%
## Training the dataset

regressor.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
regressor.intercept_
# Out:
# array([67.82661111])

# %%
regressor.coef_
# Out:
# array([[1.06934119]])

# %%
plt.scatter(X_train , y_train)
plt.plot(X_train ,regressor.predict(X_train) ,'b')

# %%
## Prediction for test data
y_predict_test =regressor.predict(X_test)

# %%
y_predict_test
# Out:
# array([[68.26402932],
#        [69.01953125],
#        [65.63819945],
#        [68.90712731],
#        [69.0416435 ],
#        [67.96459258],
#        [67.61263925],
#        [67.41731436],
#        [68.95503719],
#        [67.9839408 ],
#        [69.24710317],
#        [66.17902827],
#        [67.84389654],
#        [66.77329503],
#        [67.90194121],
#        [67.07457446],
#        [70.48446792],
#        [67.25239382],
#        [70.43655804],
#        [65.65939036]])

# %%
y_test
# Out:
#      height
# 95    70.56
# 15    71.09
# 30    69.52
# 158   72.02
# 128   68.89
# 115   68.61
# 69    67.37
# 170   69.43
# 174   73.83
# 45    68.67
# 66    69.06
# 182   66.78
# 165   67.14
# 78    69.72
# 186   68.58
# 177   65.74
# 56    70.41
# 152   66.48
# 82    70.05
# 68    67.22

# %% [markdown]
# ## Accuracy of model ,MAE ,MSE ,RMSE

# %%
from sklearn.metrics import mean_squared_error ,mean_absolute_error

# %%
mse = mean_squared_error(y_test,y_predict_test)
mae = mean_absolute_error(y_test ,y_predict_test)
rmse = np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 3.9052286303138963
# 1.4609924781871477
# 1.9761651323494949

# %% [markdown]
# ## Accuracy of the model r-squared , adjusted r squared

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test , y_predict_test)*100

# %%
score
# Out:
# -4.290644623698681

# %% [markdown]
# ## Adjusted r sqr

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# -4.584569325015274
